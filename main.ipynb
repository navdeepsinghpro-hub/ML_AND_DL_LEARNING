# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6,7])

# %%
arr

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'age':[1,2,3,4,5,6,7,8],
    'sal':[20,30,33,39,44,56,77,99]
})

# %%
df
# Out:
#    age  sal
# 0    1   20
# 1    2   30
# 2    3   33
# 3    4   39
# 4    5   44
# 5    6   56
# 6    7   77
# 7    8   99

# %%
import seaborn as sns

# %%
sns.histplot(x=df['age'], kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>
