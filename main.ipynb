# %%
import numpy as np
from scipy.stats import norm

# %%
sample = [172,174,168,169,171,173,175,170,169, 172]
population_mean = 170
population_std = 3
samp_mean = np.mean(sample)
n = len(sample)

# %%
z_score = (samp_mean - population_mean) / (population_std / np.sqrt(n))

# %%
z_score
# Out:
# np.float64(1.3703203194063098)

# %%
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# %%
p_value
# Out:
# np.float64(0.17058693287143756)

# %%
alpha = 0.05

# %%
from scipy import stats

# %%
s = [172,174,168,169,171,173,175,170,169, 172]

# %%
s_mean = np.mean(s)
s_std = np.std(s,ddof = 1)

# %%
n = len(s)
m_population = 170

# %%
t_stats = (s_mean - m_population) / (s_std / np.sqrt(n))

# %%
t_stats
# Out:
# np.float64(1.7782469350914734)

# %%
pvalue = 2 * (1-stats.t.cdf(abs(t_stats),df = n - 1))

# %%
pvalue
# Out:
# np.float64(0.10907771593031335)

# %%
alpla = 0.05
